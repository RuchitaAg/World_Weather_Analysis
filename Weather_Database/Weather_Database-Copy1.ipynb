# %%
#import dependencies
import pandas as pd
import numpy as np
import gmaps
# Import the API key.
from Config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 781

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Import the requests library.
import requests

# Import the API key.
from Config import weather_api_key


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(20)
        
        
    # Starting URL for Weather Map API Call.
    url = "http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&AppID=" + weather_api_key
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
       
        # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | esperance
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | mingguang
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | debre tabor
# Processing Record 6 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 1 | castro
# Processing Record 8 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 1 | flinders
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | hami
# Processing Record 12 of Set 1 | iqaluit
# Processing Record 13 of Set 1 | abu dhabi
# Processing Record 14 of Set 1 | tuy hoa
# Processing Record 15 of Set 1 | sola
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | gamba
# Processing Record 18 of Set 1 | aswan
# Processing Record 19 of Set 1 | half moon bay
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | nikolskoye
# Processing Record 22 of Set 1 | ust-kuyga
# Processing Record 23 of Set 1 | gornyy
# Processing Record 24 of Set 1 | pundaguitan
# Processing Record 25 of Set 1 | la ronge
# Processing Record 26 of Set 1 | priiskovyy
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 1 | airai
# Processing Record 30 of Set 1 | kaitangata
# Processing Record 31 of Set 1 | berndorf
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | kokkola
# Processing Record 34 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | santa maria da vitoria
# Processing Record 37 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 1 | sitka
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 1 | tiksi
# Processing Record 42 of Set 1 | clarence town
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | monrovia
# Processing Record 46 of Set 1 | codrington
# Processing Record 47 of Set 1 | clyde river
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | husavik
# Processing Record 50 of Set 1 | marsa matruh
# Processing Record 1 of Set 2 | torbay
# Processing Record 2 of Set 2 | cidreira
# Processing Record 3 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | tura
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | paamiut
# Processing Record 8 of Set 2 | almaznyy
# Processing Record 9 of Set 2 | ahipara
# Processing Record 10 of Set 2 | khatanga
# Processing Record 11 of Set 2 | severo-kurilsk
# Processing Record 12 of Set 2 | nakamura
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | pevek
# Processing Record 19 of Set 2 | ayagoz
# Processing Record 20 of Set 2 | son tay
# Processing Record 21 of Set 2 | tasiilaq
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 2 | ugoofaaru
# Processing Record 25 of Set 2 | east london
# Processing Record 26 of Set 2 | oksfjord
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | tuktoyaktuk
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | pangody
# Processing Record 31 of Set 2 | chico
# Processing Record 32 of Set 2 | cairns
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | isangel
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | mugur-aksy
# Processing Record 37 of Set 2 | kieta
# Processing Record 38 of Set 2 | cherskiy
# Processing Record 39 of Set 2 | klaksvik
# Processing Record 40 of Set 2 | upernavik
# Processing Record 41 of Set 2 | daru
# Processing Record 42 of Set 2 | dudinka
# Processing Record 43 of Set 2 | bilibino
# Processing Record 44 of Set 2 | hithadhoo
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 | presidencia roque saenz pena
# Processing Record 47 of Set 2 | osinki
# Processing Record 48 of Set 2 | vuktyl
# Processing Record 49 of Set 2 | vaini
# Processing Record 50 of Set 2 | zonguldak
# Processing Record 1 of Set 3 | kupang
# Processing Record 2 of Set 3 | sistranda
# Processing Record 3 of Set 3 | solnechnyy
# Processing Record 4 of Set 3 | pathein
# Processing Record 5 of Set 3 | provideniya
# Processing Record 6 of Set 3 | santo tomas
# Processing Record 7 of Set 3 | yar-sale
# Processing Record 8 of Set 3 | ballina
# Processing Record 9 of Set 3 | kapaa
# Processing Record 10 of Set 3 | marrakesh
# Processing Record 11 of Set 3 | golspie
# Processing Record 12 of Set 3 | yumen
# Processing Record 13 of Set 3 | yerbogachen
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | fort frances
# Processing Record 16 of Set 3 | tupiza
# Processing Record 17 of Set 3 | avera
# Processing Record 18 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 3 | oum hadjer
# Processing Record 21 of Set 3 | tala
# Processing Record 22 of Set 3 | saint-pierre
# Processing Record 23 of Set 3 | yeppoon
# Processing Record 24 of Set 3 | tateyama
# Processing Record 25 of Set 3 | grand gaube
# Processing Record 26 of Set 3 | qaqortoq
# Processing Record 27 of Set 3 | portland
# Processing Record 28 of Set 3 | bambous virieux
# Processing Record 29 of Set 3 | verkhoyansk
# Processing Record 30 of Set 3 | bengkulu
# Processing Record 31 of Set 3 | egvekinot
# Processing Record 32 of Set 3 | beira
# Processing Record 33 of Set 3 | constitucion
# Processing Record 34 of Set 3 | amqui
# Processing Record 35 of Set 3 | hongjiang
# Processing Record 36 of Set 3 | saint george
# Processing Record 37 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 3 | catamarca
# Processing Record 39 of Set 3 | port alfred
# Processing Record 40 of Set 3 | algiers
# Processing Record 41 of Set 3 | vila franca do campo
# Processing Record 42 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | ikalamavony
# Processing Record 46 of Set 3 | bluff
# Processing Record 47 of Set 3 | champerico
# Processing Record 48 of Set 3 | kodiak
# Processing Record 49 of Set 3 | jamestown
# Processing Record 50 of Set 3 | lluta
# Processing Record 1 of Set 4 | nakusp
# Processing Record 2 of Set 4 | beloha
# Processing Record 3 of Set 4 | ligayan
# Processing Record 4 of Set 4 | carnarvon
# Processing Record 5 of Set 4 | atherton
# Processing Record 6 of Set 4 | trinidad
# Processing Record 7 of Set 4 | kavieng
# Processing Record 8 of Set 4 | lethem
# Processing Record 9 of Set 4 | bubaque
# Processing Record 10 of Set 4 | lorengau
# Processing Record 11 of Set 4 | joshimath
# Processing Record 12 of Set 4 | saldanha
# Processing Record 13 of Set 4 | montrose
# Processing Record 14 of Set 4 | nizhniy baskunchak
# Processing Record 15 of Set 4 | georgetown
# Processing Record 16 of Set 4 | hofn
# Processing Record 17 of Set 4 | broken hill
# Processing Record 18 of Set 4 | vanavara
# Processing Record 19 of Set 4 | george
# Processing Record 20 of Set 4 | indramayu
# Processing Record 21 of Set 4 | rio gallegos
# Processing Record 22 of Set 4 | moose factory
# Processing Record 23 of Set 4 | puerto del rosario
# Processing Record 24 of Set 4 | muroto
# Processing Record 25 of Set 4 | kazachinskoye
# Processing Record 26 of Set 4 | nangomba
# Processing Record 27 of Set 4 | nyurba
# Processing Record 28 of Set 4 | toba
# Processing Record 29 of Set 4 | pemberton
# Processing Record 30 of Set 4 | marawi
# Processing Record 31 of Set 4 | coihaique
# Processing Record 32 of Set 4 | san patricio
# Processing Record 33 of Set 4 | grand-lahou
# Processing Record 34 of Set 4 | santa marta de tormes
# Processing Record 35 of Set 4 | esmeralda
# Processing Record 36 of Set 4 | gladzor
# Processing Record 37 of Set 4 | sayat
# Processing Record 38 of Set 4 | zyryanka
# Processing Record 39 of Set 4 | nahrin
# Processing Record 40 of Set 4 | juneau
# Processing Record 41 of Set 4 | port elizabeth
# Processing Record 42 of Set 4 | arlit
# Processing Record 43 of Set 4 | hay river
# Processing Record 44 of Set 4 | naze
# Processing Record 45 of Set 4 | payo
# Processing Record 46 of Set 4 | gacko
# Processing Record 47 of Set 4 | souillac
# Processing Record 48 of Set 4 | zhanakorgan
# Processing Record 49 of Set 4 | russas
# Processing Record 50 of Set 4 | uvira
# Processing Record 1 of Set 5 | cayenne
# Processing Record 2 of Set 5 | sura
# Processing Record 3 of Set 5 | victoria
# Processing Record 4 of Set 5 | saint-louis
# Processing Record 5 of Set 5 | mar del plata
# Processing Record 6 of Set 5 | marigot
# Processing Record 7 of Set 5 | plettenberg bay
# Processing Record 8 of Set 5 | mocuba
# Processing Record 9 of Set 5 | tomatlan
# Processing Record 10 of Set 5 | prata
# Processing Record 11 of Set 5 | tual
# Processing Record 12 of Set 5 | shaygino
# Processing Record 13 of Set 5 | abeche
# Processing Record 14 of Set 5 | ajdabiya
# Processing Record 15 of Set 5 | shimanovsk
# Processing Record 16 of Set 5 | nueve de julio
# Processing Record 17 of Set 5 | saint anthony
# Processing Record 18 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 5 | poum
# Processing Record 20 of Set 5 | birnin kebbi
# Processing Record 21 of Set 5 | horsham
# Processing Record 22 of Set 5 | taonan
# Processing Record 23 of Set 5 | comodoro rivadavia
# Processing Record 24 of Set 5 | burnie
# Processing Record 25 of Set 5 | jabinyanah
# Processing Record 26 of Set 5 | walvis bay
# Processing Record 27 of Set 5 | shrewsbury
# Processing Record 28 of Set 5 | namatanai
# Processing Record 29 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 5 | reconquista
# Processing Record 31 of Set 5 | touros
# Processing Record 32 of Set 5 | homer
# Processing Record 33 of Set 5 | tuatapere
# Processing Record 34 of Set 5 | victor harbor
# Processing Record 35 of Set 5 | biak
# Processing Record 36 of Set 5 | balta
# Processing Record 37 of Set 5 | cabra
# Processing Record 38 of Set 5 | brockville
# Processing Record 39 of Set 5 | bathsheba
# Processing Record 40 of Set 5 | malaya serdoba
# Processing Record 41 of Set 5 | alekseyevskoye
# Processing Record 42 of Set 5 | nome
# Processing Record 43 of Set 5 | aguimes
# Processing Record 44 of Set 5 | sao joao da barra
# Processing Record 45 of Set 5 | te anau
# Processing Record 46 of Set 5 | ostrovnoy
# Processing Record 47 of Set 5 | roald
# Processing Record 48 of Set 5 | islamkot
# Processing Record 49 of Set 5 | talawdi
# City not found. Skipping...
# Processing Record 50 of Set 5 | conceicao do araguaia
# Processing Record 1 of Set 6 | indianola
# Processing Record 2 of Set 6 | atikokan
# Processing Record 3 of Set 6 | coquimbo
# Processing Record 4 of Set 6 | dalby
# Processing Record 5 of Set 6 | haverfordwest
# Processing Record 6 of Set 6 | hasaki
# Processing Record 7 of Set 6 | korla
# Processing Record 8 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 6 | port macquarie
# Processing Record 10 of Set 6 | ucluelet
# Processing Record 11 of Set 6 | at-bashi
# Processing Record 12 of Set 6 | murgab
# Processing Record 13 of Set 6 | domoni
# Processing Record 14 of Set 6 | ponta do sol
# Processing Record 15 of Set 6 | saint-lo
# Processing Record 16 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 6 | richards bay
# Processing Record 18 of Set 6 | katsuura
# Processing Record 19 of Set 6 | broome
# Processing Record 20 of Set 6 | kruisfontein
# Processing Record 21 of Set 6 | novi
# Processing Record 22 of Set 6 | esperanza
# Processing Record 23 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 6 | dubai
# Processing Record 25 of Set 6 | chuy
# Processing Record 26 of Set 6 | labuhan
# Processing Record 27 of Set 6 | szamotuly
# Processing Record 28 of Set 6 | crotone
# Processing Record 29 of Set 6 | norman wells
# Processing Record 30 of Set 6 | metro
# Processing Record 31 of Set 6 | gornopravdinsk
# Processing Record 32 of Set 6 | grand-santi
# Processing Record 33 of Set 6 | north platte
# Processing Record 34 of Set 6 | southbridge
# Processing Record 35 of Set 6 | sayyan
# Processing Record 36 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 6 | eganville
# Processing Record 38 of Set 6 | krasnoselkup
# Processing Record 39 of Set 6 | atuona
# Processing Record 40 of Set 6 | mugumu
# Processing Record 41 of Set 6 | safaqis
# City not found. Skipping...
# Processing Record 42 of Set 6 | biltine
# Processing Record 43 of Set 6 | belyy yar
# Processing Record 44 of Set 6 | quirinopolis
# Processing Record 45 of Set 6 | oranjemund
# Processing Record 46 of Set 6 | saint-augustin
# Processing Record 47 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 6 | rundu
# Processing Record 49 of Set 6 | barranca
# Processing Record 50 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 7 | tabou
# Processing Record 2 of Set 7 | lata
# Processing Record 3 of Set 7 | cap malheureux
# Processing Record 4 of Set 7 | bethel
# Processing Record 5 of Set 7 | dingle
# Processing Record 6 of Set 7 | jalor
# Processing Record 7 of Set 7 | bandarbeyla
# Processing Record 8 of Set 7 | lavrentiya
# Processing Record 9 of Set 7 | awbari
# Processing Record 10 of Set 7 | ossora
# Processing Record 11 of Set 7 | kamaishi
# Processing Record 12 of Set 7 | lalian
# Processing Record 13 of Set 7 | chipinge
# Processing Record 14 of Set 7 | geraldton
# Processing Record 15 of Set 7 | sisimiut
# Processing Record 16 of Set 7 | yamada
# Processing Record 17 of Set 7 | shu
# Processing Record 18 of Set 7 | denpasar
# Processing Record 19 of Set 7 | ancud
# Processing Record 20 of Set 7 | pryazha
# Processing Record 21 of Set 7 | prince rupert
# Processing Record 22 of Set 7 | skibbereen
# Processing Record 23 of Set 7 | provost
# Processing Record 24 of Set 7 | gimli
# Processing Record 25 of Set 7 | houma
# Processing Record 26 of Set 7 | aquiraz
# Processing Record 27 of Set 7 | polonne
# Processing Record 28 of Set 7 | ishinomaki
# Processing Record 29 of Set 7 | severo-zadonsk
# Processing Record 30 of Set 7 | napier
# Processing Record 31 of Set 7 | hammerfest
# Processing Record 32 of Set 7 | pingdingshan
# Processing Record 33 of Set 7 | one hundred mile house
# City not found. Skipping...
# Processing Record 34 of Set 7 | dickinson
# Processing Record 35 of Set 7 | olafsvik
# Processing Record 36 of Set 7 | dunedin
# Processing Record 37 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 7 | deputatskiy
# Processing Record 39 of Set 7 | mahebourg
# Processing Record 40 of Set 7 | buala
# Processing Record 41 of Set 7 | dashitou
# Processing Record 42 of Set 7 | fairbanks
# Processing Record 43 of Set 7 | fortuna
# Processing Record 44 of Set 7 | pell city
# Processing Record 45 of Set 7 | kasempa
# Processing Record 46 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 7 | doha
# Processing Record 48 of Set 7 | berlevag
# Processing Record 49 of Set 7 | meulaboh
# Processing Record 50 of Set 7 | luderitz
# Processing Record 1 of Set 8 | fontaine
# Processing Record 2 of Set 8 | sibu
# Processing Record 3 of Set 8 | muravlenko
# Processing Record 4 of Set 8 | da nang
# Processing Record 5 of Set 8 | maniwaki
# Processing Record 6 of Set 8 | alice springs
# Processing Record 7 of Set 8 | caravelas
# Processing Record 8 of Set 8 | pampas
# Processing Record 9 of Set 8 | itarema
# Processing Record 10 of Set 8 | ilulissat
# Processing Record 11 of Set 8 | pecos
# Processing Record 12 of Set 8 | suao
# City not found. Skipping...
# Processing Record 13 of Set 8 | pisco
# Processing Record 14 of Set 8 | ruteng
# Processing Record 15 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 8 | ukiah
# Processing Record 17 of Set 8 | cockburn town
# Processing Record 18 of Set 8 | leningradskiy
# Processing Record 19 of Set 8 | riyadh
# Processing Record 20 of Set 8 | westport
# Processing Record 21 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 8 | sabzevar
# Processing Record 23 of Set 8 | novobureyskiy
# Processing Record 24 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 8 | lakes entrance
# Processing Record 26 of Set 8 | suslovo
# Processing Record 27 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 8 | ixtapa
# Processing Record 29 of Set 8 | aklavik
# Processing Record 30 of Set 8 | faanui
# Processing Record 31 of Set 8 | morristown
# Processing Record 32 of Set 8 | rio grande
# Processing Record 33 of Set 8 | perigueux
# Processing Record 34 of Set 8 | beringovskiy
# Processing Record 35 of Set 8 | chokurdakh
# Processing Record 36 of Set 8 | teya
# Processing Record 37 of Set 8 | baghmara
# Processing Record 38 of Set 8 | yulara
# Processing Record 39 of Set 8 | santa cruz de la palma
# Processing Record 40 of Set 8 | umba
# Processing Record 41 of Set 8 | port augusta
# Processing Record 42 of Set 8 | sokoto
# Processing Record 43 of Set 8 | atbasar
# Processing Record 44 of Set 8 | vostok
# Processing Record 45 of Set 8 | abengourou
# Processing Record 46 of Set 8 | salima
# Processing Record 47 of Set 8 | omboue
# Processing Record 48 of Set 8 | sur
# Processing Record 49 of Set 8 | muros
# Processing Record 50 of Set 8 | gurupa
# Processing Record 1 of Set 9 | constantine
# Processing Record 2 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 3 of Set 9 | littleton
# Processing Record 4 of Set 9 | sinegorye
# Processing Record 5 of Set 9 | gallup
# Processing Record 6 of Set 9 | rio negrinho
# Processing Record 7 of Set 9 | petauke
# Processing Record 8 of Set 9 | yantal
# Processing Record 9 of Set 9 | pesqueira
# Processing Record 10 of Set 9 | lompoc
# Processing Record 11 of Set 9 | kidal
# Processing Record 12 of Set 9 | pedernales
# Processing Record 13 of Set 9 | muisne
# Processing Record 14 of Set 9 | caala
# Processing Record 15 of Set 9 | asau
# Processing Record 16 of Set 9 | rognan
# Processing Record 17 of Set 9 | samana
# Processing Record 18 of Set 9 | kapoeta
# Processing Record 19 of Set 9 | port moresby
# Processing Record 20 of Set 9 | benguela
# Processing Record 21 of Set 9 | nueva helvecia
# Processing Record 22 of Set 9 | cabo san lucas
# Processing Record 23 of Set 9 | otavi
# Processing Record 24 of Set 9 | norrkoping
# Processing Record 25 of Set 9 | acapulco
# Processing Record 26 of Set 9 | margate
# Processing Record 27 of Set 9 | felanitx
# Processing Record 28 of Set 9 | sibolga
# Processing Record 29 of Set 9 | talnakh
# Processing Record 30 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 31 of Set 9 | laguna
# Processing Record 32 of Set 9 | shingu
# Processing Record 33 of Set 9 | sao filipe
# Processing Record 34 of Set 9 | vestmannaeyjar
# Processing Record 35 of Set 9 | itabira
# Processing Record 36 of Set 9 | sorong
# Processing Record 37 of Set 9 | asfi
# Processing Record 38 of Set 9 | lerwick
# Processing Record 39 of Set 9 | grindavik
# Processing Record 40 of Set 9 | panalingaan
# Processing Record 41 of Set 9 | olinda
# Processing Record 42 of Set 9 | makungu
# Processing Record 43 of Set 9 | niamey
# Processing Record 44 of Set 9 | san bartolome de tirajana
# Processing Record 45 of Set 9 | honiara
# Processing Record 46 of Set 9 | jinchengjiang
# City not found. Skipping...
# Processing Record 47 of Set 9 | nishihara
# Processing Record 48 of Set 9 | goure
# Processing Record 49 of Set 9 | beyla
# Processing Record 50 of Set 9 | okhotsk
# Processing Record 1 of Set 10 | antalaha
# Processing Record 2 of Set 10 | ternate
# Processing Record 3 of Set 10 | kudahuvadhoo
# Processing Record 4 of Set 10 | ust-kalmanka
# Processing Record 5 of Set 10 | edd
# Processing Record 6 of Set 10 | amapa
# Processing Record 7 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 8 of Set 10 | nampula
# Processing Record 9 of Set 10 | kavaratti
# Processing Record 10 of Set 10 | wawa
# Processing Record 11 of Set 10 | tilichiki
# Processing Record 12 of Set 10 | chernyshevskiy
# Processing Record 13 of Set 10 | igarka
# Processing Record 14 of Set 10 | varkaus
# Processing Record 15 of Set 10 | maarianhamina
# Processing Record 16 of Set 10 | kalispell
# Processing Record 17 of Set 10 | kavali
# Processing Record 18 of Set 10 | goderich
# Processing Record 19 of Set 10 | tuscaloosa
# Processing Record 20 of Set 10 | fredericton
# Processing Record 21 of Set 10 | ocos
# Processing Record 22 of Set 10 | faya
# Processing Record 23 of Set 10 | brae
# Processing Record 24 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 25 of Set 10 | miri
# Processing Record 26 of Set 10 | caxito
# Processing Record 27 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 28 of Set 10 | gobabis
# Processing Record 29 of Set 10 | westonaria
# Processing Record 30 of Set 10 | araouane
# Processing Record 31 of Set 10 | diamantino
# Processing Record 32 of Set 10 | sitges
# Processing Record 33 of Set 10 | dengzhou
# Processing Record 34 of Set 10 | camacupa
# Processing Record 35 of Set 10 | codajas
# Processing Record 36 of Set 10 | a
# City not found. Skipping...
# Processing Record 37 of Set 10 | mount isa
# Processing Record 38 of Set 10 | san quintin
# Processing Record 39 of Set 10 | bosaso
# Processing Record 40 of Set 10 | galveston
# Processing Record 41 of Set 10 | mitsamiouli
# Processing Record 42 of Set 10 | nikolayevsk-na-amure
# Processing Record 43 of Set 10 | fuling
# Processing Record 44 of Set 10 | adelaide
# Processing Record 45 of Set 10 | astoria
# Processing Record 46 of Set 10 | tubuala
# Processing Record 47 of Set 10 | lyuban
# Processing Record 48 of Set 10 | tambopata
# Processing Record 49 of Set 10 | kawalu
# Processing Record 50 of Set 10 | krasnyy chikoy
# Processing Record 1 of Set 11 | magaria
# Processing Record 2 of Set 11 | jonkoping
# Processing Record 3 of Set 11 | takoradi
# Processing Record 4 of Set 11 | amparafaravola
# Processing Record 5 of Set 11 | ouesso
# Processing Record 6 of Set 11 | port-gentil
# Processing Record 7 of Set 11 | tikhvin
# Processing Record 8 of Set 11 | tessalit
# Processing Record 9 of Set 11 | nanma
# Processing Record 10 of Set 11 | makurdi
# Processing Record 11 of Set 11 | mount gambier
# Processing Record 12 of Set 11 | lagoa
# Processing Record 13 of Set 11 | tome
# Processing Record 14 of Set 11 | bauta
# Processing Record 15 of Set 11 | rosetown
# Processing Record 16 of Set 11 | sabang
# Processing Record 17 of Set 11 | bako
# Processing Record 18 of Set 11 | polunochnoye
# Processing Record 19 of Set 11 | salalah
# Processing Record 20 of Set 11 | rocha
# Processing Record 21 of Set 11 | varzea da palma
# Processing Record 22 of Set 11 | riberalta
# Processing Record 23 of Set 11 | kepno
# Processing Record 24 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 11 | teguldet
# Processing Record 26 of Set 11 | alexandria
# Processing Record 27 of Set 11 | japura
# Processing Record 28 of Set 11 | shahpur
# Processing Record 29 of Set 11 | huarmey
# Processing Record 30 of Set 11 | knysna
# Processing Record 31 of Set 11 | khani
# Processing Record 32 of Set 11 | malanje
# Processing Record 33 of Set 11 | jalu
# Processing Record 34 of Set 11 | kahului
# Processing Record 35 of Set 11 | emden
# Processing Record 36 of Set 11 | virginia beach
# Processing Record 37 of Set 11 | dombarovskiy
# Processing Record 38 of Set 11 | djibo
# Processing Record 39 of Set 11 | guerrero negro
# Processing Record 40 of Set 11 | thomasville
# Processing Record 41 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 11 | port lincoln
# Processing Record 43 of Set 11 | sendafa
# Processing Record 44 of Set 11 | panzhihua
# Processing Record 45 of Set 11 | lovozero
# Processing Record 46 of Set 11 | sao jose da coroa grande
# Processing Record 47 of Set 11 | viedma
# Processing Record 48 of Set 11 | lufilufi
# Processing Record 49 of Set 11 | narsaq
# Processing Record 50 of Set 11 | batticaloa
# Processing Record 1 of Set 12 | cururupu
# Processing Record 2 of Set 12 | necochea
# Processing Record 3 of Set 12 | sinnamary
# Processing Record 4 of Set 12 | ermelo
# Processing Record 5 of Set 12 | pacific grove
# Processing Record 6 of Set 12 | ewa beach
# Processing Record 7 of Set 12 | tutoia
# Processing Record 8 of Set 12 | bayji
# Processing Record 9 of Set 12 | zemio
# Processing Record 10 of Set 12 | polessk
# Processing Record 11 of Set 12 | barroquinha
# Processing Record 12 of Set 12 | abancay
# Processing Record 13 of Set 12 | baton rouge
# Processing Record 14 of Set 12 | wodonga
# Processing Record 15 of Set 12 | shimoda
# Processing Record 16 of Set 12 | henties bay
# Processing Record 17 of Set 12 | tecoanapa
# Processing Record 18 of Set 12 | sao desiderio
# Processing Record 19 of Set 12 | campbell river
# Processing Record 20 of Set 12 | tayu
# Processing Record 21 of Set 12 | vardo
# Processing Record 22 of Set 12 | maniitsoq
# Processing Record 23 of Set 12 | carrick-on-suir
# Processing Record 24 of Set 12 | mabaruma
# Processing Record 25 of Set 12 | mairana
# Processing Record 26 of Set 12 | yamethin
# Processing Record 27 of Set 12 | paragominas
# Processing Record 28 of Set 12 | sao raimundo nonato
# Processing Record 29 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 12 | acari
# Processing Record 31 of Set 12 | palana
# Processing Record 32 of Set 12 | amarante
# Processing Record 33 of Set 12 | north bend
# Processing Record 34 of Set 12 | dusti
# Processing Record 35 of Set 12 | pimentel
# Processing Record 36 of Set 12 | bend
# Processing Record 37 of Set 12 | boshnyakovo
# Processing Record 38 of Set 12 | havoysund
# Processing Record 39 of Set 12 | impfondo
# Processing Record 40 of Set 12 | abilene
# Processing Record 41 of Set 12 | wilmington
# Processing Record 42 of Set 12 | cananea
# Processing Record 43 of Set 12 | pringsewu
# Processing Record 44 of Set 12 | san lazaro
# Processing Record 45 of Set 12 | choma
# Processing Record 46 of Set 12 | olavarria
# Processing Record 47 of Set 12 | weyburn
# Processing Record 48 of Set 12 | buchanan
# Processing Record 49 of Set 12 | ormara
# Processing Record 50 of Set 12 | zelenogorskiy
# Processing Record 1 of Set 13 | rawson
# Processing Record 2 of Set 13 | kissidougou
# Processing Record 3 of Set 13 | oriximina
# Processing Record 4 of Set 13 | nushki
# Processing Record 5 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 13 | zhigansk
# Processing Record 7 of Set 13 | tefe
# Processing Record 8 of Set 13 | palmer
# Processing Record 9 of Set 13 | heilbron
# Processing Record 10 of Set 13 | bonthe
# Processing Record 11 of Set 13 | mastic beach
# Processing Record 12 of Set 13 | xining
# Processing Record 13 of Set 13 | medvezhyegorsk
# Processing Record 14 of Set 13 | botwood
# Processing Record 15 of Set 13 | evanston
# Processing Record 16 of Set 13 | manokwari
# Processing Record 17 of Set 13 | catalina
# Processing Record 18 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 19 of Set 13 | vihti
# Processing Record 20 of Set 13 | sangmelima
# Processing Record 21 of Set 13 | bagotville
# Processing Record 22 of Set 13 | robertson
# Processing Record 23 of Set 13 | dwarka
# Processing Record 24 of Set 13 | senneterre
# Processing Record 25 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 26 of Set 13 | mayumba
# Processing Record 27 of Set 13 | pishin
# Processing Record 28 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 13 | manzil tamim
# City not found. Skipping...
# Processing Record 30 of Set 13 | nelson
# Processing Record 31 of Set 13 | talara
# Processing Record 32 of Set 13 | furth im wald
# Processing Record 33 of Set 13 | hamilton
# Processing Record 34 of Set 13 | umm kaddadah
# Processing Record 35 of Set 13 | languyan
# Processing Record 36 of Set 13 | inta
# Processing Record 37 of Set 13 | lasa
# Processing Record 38 of Set 13 | gazojak
# Processing Record 39 of Set 13 | ayan
# Processing Record 40 of Set 13 | bonga
# Processing Record 41 of Set 13 | kayes
# Processing Record 42 of Set 13 | adre
# Processing Record 43 of Set 13 | olot
# Processing Record 44 of Set 13 | santa rosa
# Processing Record 45 of Set 13 | katha
# City not found. Skipping...
# Processing Record 46 of Set 13 | dhidhdhoo
# Processing Record 47 of Set 13 | bartica
# Processing Record 48 of Set 13 | adrar
# Processing Record 49 of Set 13 | abasolo
# Processing Record 50 of Set 13 | ugep
# Processing Record 1 of Set 14 | sorland
# Processing Record 2 of Set 14 | trofors
# Processing Record 3 of Set 14 | manono
# Processing Record 4 of Set 14 | abadan
# Processing Record 5 of Set 14 | port blair
# Processing Record 6 of Set 14 | saint-francois
# Processing Record 7 of Set 14 | mutata
# Processing Record 8 of Set 14 | palmas
# Processing Record 9 of Set 14 | azare
# Processing Record 10 of Set 14 | otradnoye
# Processing Record 11 of Set 14 | sanmenxia
# Processing Record 12 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 14 | harper
# Processing Record 14 of Set 14 | bulembu
# Processing Record 15 of Set 14 | tarskoye
# Processing Record 16 of Set 14 | inhambane
# Processing Record 17 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 18 of Set 14 | atar
# Processing Record 19 of Set 14 | brigantine
# Processing Record 20 of Set 14 | timra
# Processing Record 21 of Set 14 | mendi
# Processing Record 22 of Set 14 | sobolevo
# Processing Record 23 of Set 14 | male
# Processing Record 24 of Set 14 | hambantota
# Processing Record 25 of Set 14 | oshkosh
# Processing Record 26 of Set 14 | gisborne
# Processing Record 27 of Set 14 | andenes
# Processing Record 28 of Set 14 | seoul
# Processing Record 29 of Set 14 | palmas bellas
# Processing Record 30 of Set 14 | miles city
# Processing Record 31 of Set 14 | telsiai
# Processing Record 32 of Set 14 | tautira
# Processing Record 33 of Set 14 | am timan
# Processing Record 34 of Set 14 | abiy adi
# City not found. Skipping...
# Processing Record 35 of Set 14 | maues
# Processing Record 36 of Set 14 | vagur
# Processing Record 37 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 14 | kununurra
# Processing Record 39 of Set 14 | zheleznodorozhnyy
# Processing Record 40 of Set 14 | neiafu
# Processing Record 41 of Set 14 | tekeli
# Processing Record 42 of Set 14 | behshahr
# Processing Record 43 of Set 14 | paita
# Processing Record 44 of Set 14 | conceicao do coite
# Processing Record 45 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 14 | pithora
# Processing Record 47 of Set 14 | payson
# Processing Record 48 of Set 14 | general roca
# Processing Record 49 of Set 14 | felipe carrillo puerto
# Processing Record 50 of Set 14 | svetlogorsk
# Processing Record 1 of Set 15 | borogontsy
# Processing Record 2 of Set 15 | camacha
# Processing Record 3 of Set 15 | mazagao
# Processing Record 4 of Set 15 | san ramon
# Processing Record 5 of Set 15 | carnot
# Processing Record 6 of Set 15 | springbok
# Processing Record 7 of Set 15 | nizhniy kuranakh
# Processing Record 8 of Set 15 | san antero
# Processing Record 9 of Set 15 | wanning
# Processing Record 10 of Set 15 | pochutla
# Processing Record 11 of Set 15 | letka
# Processing Record 12 of Set 15 | salym
# Processing Record 13 of Set 15 | haines junction
# Processing Record 14 of Set 15 | tiznit
# Processing Record 15 of Set 15 | gat
# Processing Record 16 of Set 15 | port lavaca
# Processing Record 17 of Set 15 | bontang
# Processing Record 18 of Set 15 | nurobod
# Processing Record 19 of Set 15 | college
# Processing Record 20 of Set 15 | kyabe
# Processing Record 21 of Set 15 | lambarene
# Processing Record 22 of Set 15 | gisors
# Processing Record 23 of Set 15 | saint-andre-avellin
# Processing Record 24 of Set 15 | letlhakane
# Processing Record 25 of Set 15 | khorixas
# Processing Record 26 of Set 15 | havre-saint-pierre
# Processing Record 27 of Set 15 | nantucket
# Processing Record 28 of Set 15 | freeport
# Processing Record 29 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 15 | mackay
# Processing Record 31 of Set 15 | itoman
# Processing Record 32 of Set 15 | kargasok
# Processing Record 33 of Set 15 | alihe
# Processing Record 34 of Set 15 | martin
# Processing Record 35 of Set 15 | epe
# Processing Record 36 of Set 15 | kainantu
# Processing Record 37 of Set 15 | uribia
# Processing Record 38 of Set 15 | aranos
# Processing Record 39 of Set 15 | byron bay
# Processing Record 40 of Set 15 | garowe
# Processing Record 41 of Set 15 | vila velha
# Processing Record 42 of Set 15 | ostersund
# Processing Record 43 of Set 15 | piet retief
# Processing Record 44 of Set 15 | vao
# Processing Record 45 of Set 15 | padang
# Processing Record 46 of Set 15 | kirakira
# Processing Record 47 of Set 15 | nachingwea
# Processing Record 48 of Set 15 | burica
# City not found. Skipping...
# Processing Record 49 of Set 15 | marsh harbour
# Processing Record 50 of Set 15 | santa maria
# Processing Record 1 of Set 16 | salinopolis
# Processing Record 2 of Set 16 | belmonte
# Processing Record 3 of Set 16 | alappuzha
# Processing Record 4 of Set 16 | umm lajj
# Processing Record 5 of Set 16 | puro
# Processing Record 6 of Set 16 | pitangui
# Processing Record 7 of Set 16 | apache junction
# Processing Record 8 of Set 16 | ginda
# Processing Record 9 of Set 16 | ambovombe
# Processing Record 10 of Set 16 | susanville
# Processing Record 11 of Set 16 | ola
# Processing Record 12 of Set 16 | katherine
# Processing Record 13 of Set 16 | kasongo-lunda
# Processing Record 14 of Set 16 | mareeba
# Processing Record 15 of Set 16 | tuzha
# Processing Record 16 of Set 16 | artyk
# City not found. Skipping...
# Processing Record 17 of Set 16 | sinjar
# Processing Record 18 of Set 16 | tabuk
# Processing Record 19 of Set 16 | shelburne
# Processing Record 20 of Set 16 | santa isabel do rio negro
# Processing Record 21 of Set 16 | samarai
# Processing Record 22 of Set 16 | tirumullaivasal
# Processing Record 23 of Set 16 | vidim
# Processing Record 24 of Set 16 | dandong
# Processing Record 25 of Set 16 | brus laguna
# Processing Record 26 of Set 16 | armidale
# Processing Record 27 of Set 16 | zharkent
# Processing Record 28 of Set 16 | ondorhaan
# City not found. Skipping...
# Processing Record 29 of Set 16 | shiyan
# Processing Record 30 of Set 16 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 31 of Set 16 | kuybyshevo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(cities)
# Out:
# 781

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Esperance      AU -33.8667  121.9000     58.06        81          39
# 1       Ushuaia      AR -54.8000  -68.3000     35.26        87          75
# 2     Mingguang      CN  32.7802  117.9638     68.58        74         100
# 3  Punta Arenas      CL -53.1500  -70.9167     39.31        75           0
# 4   Debre Tabor      ET  11.8500   38.0167     74.66        22          97
#
#    Wind Speed Current Description
# 0        5.41    scattered clouds
# 1       29.93          light snow
# 2        1.12     overcast clouds
# 3       19.57           clear sky
# 4        8.55     overcast clouds
